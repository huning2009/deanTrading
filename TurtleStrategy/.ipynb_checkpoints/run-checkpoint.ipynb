# %%
# %matplotlib inline

from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt

from turtleEngine import BacktestingEngine

# %%
engine = BacktestingEngine()
engine.setPeriod(datetime(2014, 1, 1), datetime(2018, 12, 30))
engine.initPortfolio('test.csv', 10000000)

engine.loadData()
engine.runBacktesting()
engine.showResult()
# Out:
# 投资组合的合约代码['000300', '000905']
# 投资组合的初始价值10000000
# 000300数据加载完成，总数据量：1185
# 000905数据加载完成，总数据量：1185
# 全部数据加载完成
# 开始回放K线数据
# K线数据回放结束
# 开始统计回测结果
# ------------------------------
# 首个交易日：	2014-01-02 00:00:00
# 最后交易日：	2018-11-09 00:00:00
# 总交易日：	1185
# 盈利交易日	443
# 亏损交易日：	415
# 起始资金：	10000000
# 结束资金：	42,612,190.5
# 总收益率：	326.12%
# 年化收益：	33.17%
# 总盈亏：	32,612,190.5
# 最大回撤: 	-6,105,930.65
# 百分比最大回撤: -28.72%
# 总手续费：	0.0
# 总滑点：	0.0
# 总成交笔数：	333
# 日均盈亏：	27,520.84
# 日均手续费：	0.0
# 日均滑点：	0.0
# 日均成交笔数：	0.28
# 日均收益率：	0.14%
# 收益标准差：	1.79%
# Sharpe Ratio：	1.2

# %%
tradeList = engine.getTradeData('000300')
for trade in tradeList:
    print （%s %s %s %s@%s） %(trade.vtSymbol, trade.direction, trade.offset,
                             trade.volume, trade.price)
# Out:
#   File "<ipython-input-3-2a957e2d0d08>", line 3
#     print '%s %s %s %s@%s' %(trade.vtSymbol, trade.direction, trade.offset,
#                          ^
# SyntaxError: invalid syntax
