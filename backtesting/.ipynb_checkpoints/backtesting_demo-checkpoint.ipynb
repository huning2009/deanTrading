# %%
#%%
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
import os, sys, pathlib
sys.path.append("E:\\Desktop\\deanTrading")
from strategies.strategyEmaEma import (
    EmaEmaStrategy,
)
from datetime import datetime
# Out:
# dbpath:C:\Users\Administrator\.vntrader\database.db

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="I1909.DCE",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2019, 4, 30),
    rate=0.3/10000,
    slippage=0,
    size=100,
    pricetick=0.5,
    capital=1_000_000,
)
engine.add_strategy(EmaEmaStrategy, {
            "class_name": "EmaEmaStrategy",
            "ema_period": 22,
            "fixed_size": 1
        })
# Out:
# backtesting engine strategy setting:{'class_name': 'EmaEmaStrategy', 'ema_period': 22, 'fixed_size': 1}

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2020-01-11 15:46:22.019351	开始加载历史数据
# 2020-01-11 15:46:22.464534	加载进度：## [25%]
# 2020-01-11 15:46:22.774390	加载进度：##### [50%]
# 2020-01-11 15:46:23.234613	加载进度：####### [76%]
# 2020-01-11 15:46:23.569502	加载进度：########## [100%]
# 2020-01-11 15:46:23.569502	历史数据加载完成，数据量：28350
# 2020-01-11 15:46:23.597544	策略初始化完成
# 2020-01-11 15:46:23.598547	开始回放历史数据
# 2020-01-11 15:46:23.696808	历史数据回放结束
# 2020-01-11 15:46:23.697855	开始计算逐日盯市盈亏
# 2020-01-11 15:46:23.699853	逐日盯市盈亏计算完成
# 2020-01-11 15:46:23.699853	开始计算策略统计指标
# 2020-01-11 15:46:23.713890	------------------------------
# 2020-01-11 15:46:23.713890	首个交易日：	2019-02-20
# 2020-01-11 15:46:23.713890	最后交易日：	2019-04-29
# 2020-01-11 15:46:23.713890	总交易日：	48
# 2020-01-11 15:46:23.713890	盈利交易日：	23
# 2020-01-11 15:46:23.713890	亏损交易日：	25
# 2020-01-11 15:46:23.713890	起始资金：	1,000,000.00
# 2020-01-11 15:46:23.713890	结束资金：	1,000,651.47
# 2020-01-11 15:46:23.713890	总收益率：	0.07%
# 2020-01-11 15:46:23.713890	年化收益：	0.33%
# 2020-01-11 15:46:23.713890	最大回撤: 	-9,065.65
# 2020-01-11 15:46:23.713890	百分比最大回撤: -0.90%
# 2020-01-11 15:46:23.713890	最长回撤天数: 	13
# 2020-01-11 15:46:23.713890	总盈亏：	651.47
# 2020-01-11 15:46:23.713890	总手续费：	198.53
# 2020-01-11 15:46:23.713890	总滑点：	0.00
# 2020-01-11 15:46:23.713890	总成交金额：	6,617,550.00
# 2020-01-11 15:46:23.713890	总成交笔数：	111
# 2020-01-11 15:46:23.713890	日均盈亏：	13.57
# 2020-01-11 15:46:23.713890	日均手续费：	4.14
# 2020-01-11 15:46:23.713890	日均滑点：	0.00
# 2020-01-11 15:46:23.713890	日均成交金额：	137,865.62
# 2020-01-11 15:46:23.713890	日均成交笔数：	2.3125
# 2020-01-11 15:46:23.713890	日均收益率：	0.00%
# 2020-01-11 15:46:23.713890	收益标准差：	0.12%
# 2020-01-11 15:46:23.713890	Sharpe Ratio：	0.11
# 2020-01-11 15:46:23.713890	收益回撤比：	0.07

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 3, 39, 1)
setting.add_parameter("atr_ma_length", 10, 30, 1)

engine.run_ga_optimization(setting)
