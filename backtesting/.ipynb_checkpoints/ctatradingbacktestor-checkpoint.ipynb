# %%
import sys, os
from datetime import datetime
sys.path.append("E:\\Desktop\\deanTrading")
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
from CtaTrading.strategies.strategyEmaEma import EmaEmaStrategy
# Out:
# vt_setting.json
# C:\Users\Administrator\.vntrader\vt_setting.json
# OHLCData.db
# C:\Users\Administrator\.vntrader\OHLCData.db

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="SC1909.INE",
    interval="1m",
    start=datetime(2018, 1, 1),
    end=datetime(2019, 6, 3),
    rate=0.3/10000,
    slippage=0.2,
    size=1000,
    pricetick=0.1,
    capital=100000,
)
engine.add_strategy(EmaEmaStrategy, {})

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2019-06-03 13:41:04.142218	开始加载历史数据
# 2019-06-03 13:41:09.466368	历史数据加载完成，数据量：96961
# 2019-06-03 13:41:09.501497	策略初始化完成
# 2019-06-03 13:41:09.501497	开始回放历史数据
# 2019-06-03 13:41:09.948671	历史数据回放结束
# 2019-06-03 13:41:09.948671	开始计算逐日盯市盈亏
# 2019-06-03 13:41:09.951657	逐日盯市盈亏计算完成
# 2019-06-03 13:41:09.952660	开始计算策略统计指标
# 2019-06-03 13:41:09.966698	------------------------------
# 2019-06-03 13:41:09.966698	首个交易日：	2018-10-17
# 2019-06-03 13:41:09.966698	最后交易日：	2019-06-01
# 2019-06-03 13:41:09.966698	总交易日：	180
# 2019-06-03 13:41:09.966698	盈利交易日：	59
# 2019-06-03 13:41:09.966698	亏损交易日：	59
# 2019-06-03 13:41:09.966698	起始资金：	10,000.00
# 2019-06-03 13:41:09.966698	结束资金：	128,111.77
# 2019-06-03 13:41:09.966698	总收益率：	1,181.12%
# 2019-06-03 13:41:09.966698	年化收益：	1,574.82%
# 2019-06-03 13:41:09.966698	最大回撤: 	-99,254.83
# 2019-06-03 13:41:09.966698	百分比最大回撤: -65.46%
# 2019-06-03 13:41:09.966698	总盈亏：	118,111.77
# 2019-06-03 13:41:09.966698	总手续费：	2,288.23
# 2019-06-03 13:41:09.966698	总滑点：	33,000.00
# 2019-06-03 13:41:09.966698	总成交金额：	76,274,500.00
# 2019-06-03 13:41:09.966698	总成交笔数：	165
# 2019-06-03 13:41:09.966698	日均盈亏：	656.18
# 2019-06-03 13:41:09.966698	日均手续费：	12.71
# 2019-06-03 13:41:09.966698	日均滑点：	183.33
# 2019-06-03 13:41:09.966698	日均成交金额：	423,747.22
# 2019-06-03 13:41:09.966698	日均成交笔数：	0.9166666666666666
# 2019-06-03 13:41:09.966698	日均收益率：	1.42%
# 2019-06-03 13:41:09.966698	收益标准差：	11.75%
# 2019-06-03 13:41:09.966698	Sharpe Ratio：	1.87
# 2019-06-03 13:41:09.966698	收益回撤比：	18.04
