# %%
#%%
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
from vnpy.app.cta_strategy.strategies.turtle_signal_strategy import (
    TurtleSignalStrategy,
)
from datetime import datetime
# Out:
# dbpath:C:\Users\Administrator\.vntrader\database.db

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="SC1909.INE",
    interval="1m",
    start=datetime(2018, 1, 1),
    end=datetime(2019, 6, 30),
    rate=0.3/10000,
    slippage=0.2,
    size=1000,
    pricetick=0.1,
    capital=100000,
)
engine.add_strategy(TurtleSignalStrategy, {})

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2019-06-03 14:11:19.377721	开始加载历史数据
# 2019-06-03 14:11:24.672960	历史数据加载完成，数据量：96961
# 2019-06-03 14:11:25.059022	策略初始化完成
# 2019-06-03 14:11:25.059022	开始回放历史数据
# 2019-06-03 14:11:39.052249	历史数据回放结束
# 2019-06-03 14:11:39.053253	开始计算逐日盯市盈亏
# 2019-06-03 14:11:39.697969	逐日盯市盈亏计算完成
# 2019-06-03 14:11:39.698971	开始计算策略统计指标
# 2019-06-03 14:11:39.716021	------------------------------
# 2019-06-03 14:11:39.716021	首个交易日：	2018-09-27
# 2019-06-03 14:11:39.716021	最后交易日：	2019-06-01
# 2019-06-03 14:11:39.716021	总交易日：	190
# 2019-06-03 14:11:39.716021	盈利交易日：	4
# 2019-06-03 14:11:39.716021	亏损交易日：	156
# 2019-06-03 14:11:39.716021	起始资金：	100,000.00
# 2019-06-03 14:11:39.716021	结束资金：	-73,665,301.68
# 2019-06-03 14:11:39.716021	总收益率：	-73,765.30%
# 2019-06-03 14:11:39.716021	年化收益：	-93,177.22%
# 2019-06-03 14:11:39.716021	最大回撤: 	-72,992,218.76
# 2019-06-03 14:11:39.716021	百分比最大回撤: -0.00%
# 2019-06-03 14:11:39.716021	总盈亏：	-73,765,301.68
# 2019-06-03 14:11:39.716021	总手续费：	4,830,401.68
# 2019-06-03 14:11:39.716021	总滑点：	69,357,600.00
# 2019-06-03 14:11:39.716021	总成交金额：	161,013,389,300.00
# 2019-06-03 14:11:39.716021	总成交笔数：	342344
# 2019-06-03 14:11:39.716021	日均盈亏：	-388,238.43
# 2019-06-03 14:11:39.716021	日均手续费：	25,423.17
# 2019-06-03 14:11:39.716021	日均滑点：	365,040.00
# 2019-06-03 14:11:39.716021	日均成交金额：	847,438,891.05
# 2019-06-03 14:11:39.716021	日均成交笔数：	1801.8105263157895
# 2019-06-03 14:11:39.716021	日均收益率：	2.46%
# 2019-06-03 14:11:39.716021	收益标准差：	6.81%
# 2019-06-03 14:11:39.716021	Sharpe Ratio：	5.61
# 2019-06-03 14:11:39.716021	收益回撤比：	-inf
# D:\MyPrograms\Anaconda3\lib\site-packages\vnpy\app\cta_strategy\backtesting.py:386: RuntimeWarning: divide by zero encountered in double_scalars
#   return_drawdown_ratio = -total_return / max_ddpercent

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 3, 39, 1)
setting.add_parameter("atr_ma_length", 10, 30, 1)

engine.run_ga_optimization(setting)

# %%
result = _

# %%
print(result)
