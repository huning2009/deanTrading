# %%
import sys, os
from datetime import datetime
sys.path.append("E:\\Desktop\\deanTrading")
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
from CtaTrading.strategies.strategyEmaEma import EmaEmaStrategy
# Out:
# vt_setting.json
# C:\Users\Administrator\.vntrader\vt_setting.json
# OHLCData.db
# C:\Users\Administrator\.vntrader\OHLCData.db

# %%
#%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="SC1909.INE",
    interval="1m",
    start=datetime(2018, 1, 1),
    end=datetime(2019, 6, 3),
    rate=0.3/10000,
    slippage=0.2,
    size=1000,
    pricetick=0.1,
    capital=100000,
)
engine.add_strategy(EmaEmaStrategy, {})

# %%
#%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2019-06-03 14:06:19.291912	开始加载历史数据
# 2019-06-03 14:06:24.632106	历史数据加载完成，数据量：96961
# 2019-06-03 14:06:24.665194	策略初始化完成
# 2019-06-03 14:06:24.665194	开始回放历史数据
# 2019-06-03 14:06:25.108374	历史数据回放结束
# 2019-06-03 14:06:25.108374	开始计算逐日盯市盈亏
# 2019-06-03 14:06:25.111382	逐日盯市盈亏计算完成
# 2019-06-03 14:06:25.112384	开始计算策略统计指标
# 2019-06-03 14:06:25.125457	------------------------------
# 2019-06-03 14:06:25.125457	首个交易日：	2018-10-17
# 2019-06-03 14:06:25.125457	最后交易日：	2019-06-01
# 2019-06-03 14:06:25.125457	总交易日：	180
# 2019-06-03 14:06:25.125457	盈利交易日：	59
# 2019-06-03 14:06:25.125457	亏损交易日：	59
# 2019-06-03 14:06:25.125457	起始资金：	100,000.00
# 2019-06-03 14:06:25.125457	结束资金：	218,111.77
# 2019-06-03 14:06:25.125457	总收益率：	118.11%
# 2019-06-03 14:06:25.125457	年化收益：	157.48%
# 2019-06-03 14:06:25.125457	最大回撤: 	-99,254.83
# 2019-06-03 14:06:25.125457	百分比最大回撤: -41.08%
# 2019-06-03 14:06:25.125457	总盈亏：	118,111.77
# 2019-06-03 14:06:25.125457	总手续费：	2,288.23
# 2019-06-03 14:06:25.125457	总滑点：	33,000.00
# 2019-06-03 14:06:25.125457	总成交金额：	76,274,500.00
# 2019-06-03 14:06:25.125457	总成交笔数：	165
# 2019-06-03 14:06:25.125457	日均盈亏：	656.18
# 2019-06-03 14:06:25.125457	日均手续费：	12.71
# 2019-06-03 14:06:25.125457	日均滑点：	183.33
# 2019-06-03 14:06:25.125457	日均成交金额：	423,747.22
# 2019-06-03 14:06:25.125457	日均成交笔数：	0.9166666666666666
# 2019-06-03 14:06:25.125457	日均收益率：	0.43%
# 2019-06-03 14:06:25.125457	收益标准差：	4.25%
# 2019-06-03 14:06:25.125457	Sharpe Ratio：	1.58
# 2019-06-03 14:06:25.125457	收益回撤比：	2.88
